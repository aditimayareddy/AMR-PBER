# %%
import pandas as pd
import numpy as np
import geopandas as gp
clayton_prim = pd.read_csv('clayton_primary.csv', usecols = ['UNIQUE_ID', 'county', 'precinct', 'total_uss', 'total_gov'])
clayton_shp = gp.read_file('clayton_gen')

# %%
clayton_shp.plot()
# Out:
# <AxesSubplot:>

# %%
clayton_shp.head()
# Out:
#            UNIQUE_ID   county       precinct  \
# 0    063-ELLENWOOD 1  Clayton    Ellenwood 1
# 1    063-ELLENWOOD 2  Clayton    Ellenwood 2
# 2  063-FOREST PARK 1  Clayton  Forest Park 1
# 3  063-FOREST PARK 2  Clayton  Forest Park 2
# 4  063-FOREST PARK 3  Clayton  Forest Park 3
#
#                                             geometry
# 0  POLYGON ((-84.26294 33.61143, -84.26295 33.610...
# 1  POLYGON ((-84.30413 33.63318, -84.30498 33.634...
# 2  POLYGON ((-84.35076 33.61873, -84.35046 33.618...
# 3  POLYGON ((-84.35076 33.61873, -84.35177 33.619...
# 4  POLYGON ((-84.40078 33.63291, -84.40073 33.632...

# %%
clayton_prim.shape
# Out:
# (65, 5)

# %%
clayton_shp.shape
# Out:
# (70, 4)

# %%
clayton_prim[clayton_prim['precinct'] == 'jonesboro 20']
# Out:
# Empty DataFrame
# Columns: [UNIQUE_ID, county, precinct, total_uss, total_gov]
# Index: []

# %%
clayton_prim.head(40)
# Out:
#             UNIQUE_ID   county       precinct  total_uss  total_gov
# 0     063-Ellenwood 1  Clayton    Ellenwood 1        802        803
# 1     063-Ellenwood 2  Clayton    Ellenwood 2        927        930
# 2   063-Forest Park 1  Clayton  Forest Park 1        352        358
# 3   063-Forest Park 2  Clayton  Forest Park 2        376        379
# 4   063-Forest Park 3  Clayton  Forest Park 3        334        329
# 5   063-Forest Park 4  Clayton  Forest Park 4        274        278
# 6   063-Forest Park 5  Clayton  Forest Park 5        357        357
# 7   063-Forest Park 6  Clayton  Forest Park 6        207        210
# 8     063-Jonesboro 1  Clayton    Jonesboro 1        541        539
# 9    063-Jonesboro 10  Clayton   Jonesboro 10        421        422
# 10   063-Jonesboro 11  Clayton   Jonesboro 11       1022       1013
# 11   063-Jonesboro 12  Clayton   Jonesboro 12        472        474
# 12   063-Jonesboro 13  Clayton   Jonesboro 13        534        537
# ...

# %%
clayton_shp.head(40)
# Out:
#             UNIQUE_ID   county       precinct  \
# 0     063-ELLENWOOD 1  Clayton    Ellenwood 1
# 1     063-ELLENWOOD 2  Clayton    Ellenwood 2
# 2   063-FOREST PARK 1  Clayton  Forest Park 1
# 3   063-FOREST PARK 2  Clayton  Forest Park 2
# 4   063-FOREST PARK 3  Clayton  Forest Park 3
# 5   063-FOREST PARK 4  Clayton  Forest Park 4
# 6   063-FOREST PARK 5  Clayton  Forest Park 5
# 7   063-FOREST PARK 6  Clayton  Forest Park 6
# 8     063-JONESBORO 1  Clayton    Jonesboro 1
# 9    063-JONESBORO 10  Clayton   Jonesboro 10
# 10   063-JONESBORO 11  Clayton   Jonesboro 11
# 11   063-JONESBORO 12  Clayton   Jonesboro 12
# 12   063-JONESBORO 13  Clayton   Jonesboro 13
# 13   063-JONESBORO 14  Clayton   Jonesboro 14
# 14   063-JONESBORO 15  Clayton   Jonesboro 15
# 15   063-JONESBORO 16  Clayton   Jonesboro 16
# 16   063-JONESBORO 17  Clayton   Jonesboro 17
# 17   063-JONESBORO 18  Clayton   Jonesboro 18
# 18   063-JONESBORO 19  Clayton   Jonesboro 19
# ...
