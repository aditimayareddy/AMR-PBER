# %% [markdown]
# ## Alabama 2022 Primary Election Returns

# %% [markdown]
# ### Georgia 2022 Primary Election Returns
#
# ### Sections
# - <a href="#ETL">Cleaning Precinct-Level Election Results</a><br>
# - <a href="#check">Vote Totals Checks</a><br>
# - <a href ="#discrepancies"> Examine/Fix Anomalies <a/><br>
# - <a href="#readme">Creating README</a><br>
# - <a href="#exp">Exporting Cleaned Precinct-Level Dataset</a><br>
#
# #### Sources
#
# - [Alabama Primary Election Results, Precint Level](https://www.sos.alabama.gov/sites/default/files/election-data/2022-06/2022%20Primary%20Precinct%20Results.zip)
# - [Secretary of State Certified Results, Democratic Party](https://www.sos.alabama.gov/sites/default/files/election-2022/AL%20Democratic%20Party%202022%20Primary%20Results.xlsx)
# - [Secretary of State Certified Results, Republican Party](https://www.sos.alabama.gov/sites/default/files/election-2022/AL%20Republican%20Party%202022%20Primary%20Results%20Official.xlsx)

# %%
import geopandas as gp
import pandas as pd
import os
import numpy as np
import re
from collections import Counter
import AL_22_helper_functions as hlp

# %% [markdown]
# <p><a name="ETL"></a></p>
#
# ### Cleaning Precinct Level Election Returns

# %% [markdown]
# Load-In + Clean Election Results

# %%
ph_county_list = []
ar_county_list = []
clean_index = []
index_issue = []
files = os.listdir('./raw-from-source/2022 Primary Precinct Results/')

for idx, file in enumerate(files):
    #Load county files
    temp = pd.read_excel('./raw-from-source/2022 Primary Precinct Results/' + file)
    
    # Get the county name, clean "StClair" to match pattern
    county_name = file.split("-")[-1][0:-4]
    if county_name == "StClair":
        county_name = "St. Clair"
    ar_county_list.append(county_name)
        
    # Clean the party name
    temp["Party"] = temp["Party"].str.strip()
    temp["Party"] = temp["Party"].fillna("")
    
    # Create a column to pivot on
    temp["pivot_col"] = temp["Contest Title"].str.strip()+"-:-"+temp["Candidate"].str.strip()
    temp["pivot_col"] = np.where(temp["Party"]=="",temp["pivot_col"],temp["pivot_col"]+"-:-"+temp["Party"].str.strip())
    
    # Drop columns that are no longer needed
    temp.drop(["Contest Title", "Party", "Candidate"], axis = 1, inplace = True)
    
    # Add the county name to the precinct
    rename_dict = {i:i+"-:-"+county_name for i in temp.columns if i != "pivot_col"}
    temp.rename(columns = rename_dict, inplace = True)
    
    # Transpose the dataframe
    temp_transpose = temp.set_index("pivot_col").T
    temp_transpose["County"] = county_name
    temp_transpose.reset_index(inplace = True, drop = False)
    temp_transpose["County"] = county_name
    
    #Make sure cols and indexes unique
    if temp_transpose.columns.nunique() == len(temp_transpose.columns) and temp_transpose.index.is_unique:
        clean_index.append(county_name)
    else:
        index_issue.append(str(county_name) + ' ' + str(idx))
    
#     #Test to make sure all the indexes are unique
#     for val in temp_transpose.index:
#         index_testing.append(val)
#         index_df = pd.DataFrame(index_testing)
        

#     # Add to the list of counties
#     ph_county_list.append(temp_transpose)
    
#     # Concatenate into one file
#     comb = pd.concat(ph_county_list, axis = 0)

# %%
len(clean_index)
# Out:
# 66

# %%
index_issue
# Out:
# ['Madison 44']

# %%
files[44]
# Out:
# '2022-Primary-Madison.xls'

# %%
issue_file = files[44]

# %%
temp = pd.read_excel('./raw-from-source/2022 Primary Precinct Results/' + issue_file)

# %%
issue_file = files[44]
temp = pd.read_excel('./raw-from-source/2022 Primary Precinct Results/' + issue_file)
    
# Get the county name, clean "StClair" to match pattern
county_name = file.split("-")[-1][0:-4]
ar_county_list.append(county_name)
        
# Clean the party name
temp["Party"] = temp["Party"].str.strip()
temp["Party"] = temp["Party"].fillna("")
    
# Create a column to pivot on
temp["pivot_col"] = temp["Contest Title"].str.strip()+"-:-"+temp["Candidate"].str.strip()
temp["pivot_col"] = np.where(temp["Party"]=="",temp["pivot_col"],temp["pivot_col"]+"-:-"+temp["Party"].str.strip())
    
# # Drop columns that are no longer needed
# temp.drop(["Contest Title", "Party", "Candidate"], axis = 1, inplace = True)
    
# Add the county name to the precinct
rename_dict = {i:i+"-:-"+county_name for i in temp.columns if i != "pivot_col"}
temp.rename(columns = rename_dict, inplace = True)
    
# Transpose the dataframe
temp_transpose = temp.set_index("pivot_col").T
temp_transpose["County"] = county_name
temp_transpose.reset_index(inplace = True, drop = False)
temp_transpose["County"] = county_name
    
#Make sure cols and indexes unique
print(temp_transpose.columns.nunique() == len(temp_transpose.columns))
print(temp_transpose.index.is_unique)
# Out:
# False
# True

# %%
col_dups = pd.DataFrame(temp_transpose.columns.to_list())

# %%
col_dups.columns = ['cols']

# %%
col_dups['cols'].value_counts()
# Out:
# -:-Over Votes-:-DEM                                                                     4
# -:-Under Votes-:-DEM                                                                    4
# STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 53-:-Over Votes-:-DEM             1
# MADISON COUNTY DEM EXEC COMM (F). DIST 6-:-Laura Hall-:-DEM                             1
# STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, PLACE 3-:-Tobias Vogt-:-REP        1
#                                                                                        ..
# MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11-:-Under Votes-:-REP    1
# PROPOSED STATEWIDE AMENDMENT NUMBER ONE (1)-:-Yes                                       1
# GOVERNOR-:-Under Votes-:-REP                                                            1
# GOVERNOR-:-Lew Burdette-:-REP                                                           1
# STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, DISTRICT 1-:-Over Votes-:-REP      1
# Name: cols, Length: 273, dtype: int64

# %%
temp_transpose.head()
# Out:
# pivot_col                               index  \
# 0                     Contest Title-:-Winston
# 1                             Party-:-Winston
# 2                         Candidate-:-Winston
# 3          A & M UNIVERSITY NEW GYM-:-Winston
# 4                          ABSENTEE-:-Winston
#
# pivot_col REGISTERED VOTERS - TOTAL-:-Registered Voters - Total  \
# 0          REGISTERED VOTERS - TOTAL                     ...
# 1
# 2                     Registered Voters - Total
# 3                                                     5742.0
# 4                                                          0
#
# pivot_col        BALLOTS CAST - TOTAL-:-Ballots Cast - Total  \
# 0          BALLOTS CAST - TOTAL                          ...
# 1
# 2                     Ballots Cast - Total
# 3                                                      148.0
# 4                                                       1816
#
# pivot_col BALLOTS CAST - DEMOCRAT-:-Ballots Cast - Alabama Democratic P-:-DEM  \
# 0          BALLOTS CAST - DEMOCRAT                       ...
# 1                                                        DEM
# 2                     Ballots Cast - Alabama Democratic P
# 3                                                      102.0
# 4                                                        356
#
# pivot_col BALLOTS CAST - REPUBLICAN-:-Ballots Cast - Alabama Republican P-:-REP  \
# 0          BALLOTS CAST - REPUBLICAN                     ...
# 1                                                        REP
# 2                     Ballots Cast - Alabama Republican P
# 3                                                       46.0
# 4                                                       1456
#
# pivot_col BALLOTS CAST - NON-PARTISAN-:-Ballots Cast - Nonpartisan  \
# 0          BALLOTS CAST - NON-PARTISAN                   ...
# 1
# 2                     Ballots Cast - Nonpartisan
# 3                                                        0.0
# 4                                                          4
#
# pivot_col        BALLOTS CAST - BLANK-:-Ballots Cast - Blank  \
# 0          BALLOTS CAST - BLANK                          ...
# 1
# 2                     Ballots Cast - Blank
# 3                                                        0.0
# 4                                                          0
#
# pivot_col            UNITED STATES SENATOR-:-Will Boyd-:-DEM  \
# 0          UNITED STATES SENATOR                         ...
# 1                                                        DEM
# 2                     Will Boyd
# 3                                                       70.0
# 4                                                        211
#
# pivot_col        UNITED STATES SENATOR-:-Lillie Boddie-:-REP  \
# 0          UNITED STATES SENATOR                         ...
# 1                                                        REP
# 2                     Lillie Boddie
# 3                                                        0.0
# 4                                                          7
#
# pivot_col        UNITED STATES SENATOR-:-Brandaun Dean-:-DEM  ...  \
# 0          UNITED STATES SENATOR                         ...  ...
# 1                                                        DEM  ...
# 2                     Brandaun Dean                           ...
# 3                                                       13.0  ...
# 4                                                         67  ...
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11-:-Elizabeth Black-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 9 PL 9      ...
# 1                                                        REP
# 2                     Elizabeth Black
# 3                                                        NaN
# 4                                                         45
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11-:-Charles Coats-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 9 PL 9      ...
# 1                                                        REP
# 2                     Charles Coats
# 3                                                        NaN
# 4                                                         29
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11-:-William Cody Garton-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 9 PL 9      ...
# 1                                                        REP
# 2                     William Cody Garton
# 3                                                        NaN
# 4                                                         21
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11-:-Over Votes-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 9 PL 9      ...
# 1                                                        REP
# 2                     Over Votes
# 3                                                        NaN
# 4                                                          0
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11-:-Under Votes-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 9 PL 9      ...
# 1                                                        REP
# 2                     Under Votes
# 3                                                        NaN
# 4                                                         64
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 11 PL 2               TRICT 11-:-Heath B. Jones-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 11 PL 2     ...
# 1                                                        REP
# 2                     Heath B. Jones
# 3                                                        NaN
# 4                                                         19
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 11 PL 2               TRICT 11-:-Stella Stooksbury-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 11 PL 2     ...
# 1                                                        REP
# 2                     Stella Stooksbury
# 3                                                        NaN
# 4                                                          6
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 11 PL 2               TRICT 11-:-Over Votes-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 11 PL 2     ...
# 1                                                        REP
# 2                     Over Votes
# 3                                                        NaN
# 4                                                          0
#
# pivot_col MADISON COUNTY REP EXEC COMM DIST 11 PL 2               TRICT 11-:-Under Votes-:-REP  \
# 0          MADISON COUNTY REP EXEC COMM DIST 11 PL 2     ...
# 1                                                        REP
# 2                     Under Votes
# 3                                                        NaN
# 4                                                         20
#
# pivot_col   County
# 0          Winston
# 1          Winston
# 2          Winston
# 3          Winston
# 4          Winston
#
# [5 rows x 279 columns]

# %%
temp.head()
# Out:
#                              Contest Title-:-Winston Party-:-Winston  \
# 0  REGISTERED VOTERS - TOTAL                     ...
# 1  BALLOTS CAST - TOTAL                          ...
# 2  BALLOTS CAST - DEMOCRAT                       ...             DEM
# 3  BALLOTS CAST - REPUBLICAN                     ...             REP
# 4  BALLOTS CAST - NON-PARTISAN                   ...
#
#                       Candidate-:-Winston  A & M UNIVERSITY NEW GYM-:-Winston  \
# 0  Registered Voters - Total                                           5742.0
# 1  Ballots Cast - Total                                                 148.0
# 2  Ballots Cast - Alabama Democratic P                                  102.0
# 3  Ballots Cast - Alabama Republican P                                   46.0
# 4  Ballots Cast - Nonpartisan                                             0.0
#
#    ABSENTEE-:-Winston  ALDERSGATE UMC-:-Winston  ALL NATIONS-:-Winston  \
# 0                   0                    4962.0                 5571.0
# 1                1816                    1432.0                  549.0
# 2                 356                     136.0                  141.0
# 3                1456                    1295.0                  406.0
# 4                   4                       1.0                    2.0
#
#    BOB HARRISON SR_ CTR_-:-Winston  BOBO VFD-:-Winston  \
# 0                           3451.0              2659.0
# 1                            629.0               525.0
# 2                            531.0                59.0
# 3                             98.0               466.0
# 4                              0.0                 0.0
#
#    BROWNSBORO BAPT CH-:-Winston  ...  TONEY UMC-:-Winston  \
# 0                        2929.0  ...               3623.0
# 1                         679.0  ...                782.0
# 2                          54.0  ...                157.0
# 3                         625.0  ...                623.0
# 4                           0.0  ...                  2.0
#
#    TRIANA CITY HALL-:-Winston  TRINITY UNITED METHODIST-:-Winston  \
# 0                      4461.0                              6305.0
# 1                       666.0                               990.0
# 2                       322.0                               126.0
# 3                       342.0                               863.0
# 4                         2.0                                 1.0
#
#    UNIVERSITY BAPT CH-:-Winston  W HUNTSVILLE CH CHRIST-:-Winston  \
# 0                        2309.0                            3836.0
# 1                         226.0                             513.0
# 2                          35.0                             126.0
# 3                         190.0                             384.0
# 4                           1.0                               3.0
#
#    WEATHERLY HGTS BAPT-:-Winston  WEST HUNTSVILLE BAPT-:-Winston  \
# 0                         4332.0                          3467.0
# 1                         1235.0                           269.0
# 2                          117.0                            88.0
# 3                         1116.0                           179.0
# 4                            2.0                             2.0
#
#    WESTSIDE COMM_ CTR_-:-Winston  WILLOWBROOK BAPT CH-:-Winston  \
# 0                          564.0                         5980.0
# 1                           23.0                         1803.0
# 2                           16.0                          150.0
# 3                            7.0                         1649.0
# 4                            0.0                            4.0
#
#                                            pivot_col
# 0  REGISTERED VOTERS - TOTAL-:-Registered Voters ...
# 1        BALLOTS CAST - TOTAL-:-Ballots Cast - Total
# 2  BALLOTS CAST - DEMOCRAT-:-Ballots Cast - Alaba...
# 3  BALLOTS CAST - REPUBLICAN-:-Ballots Cast - Ala...
# 4  BALLOTS CAST - NON-PARTISAN-:-Ballots Cast - N...
#
# [5 rows x 80 columns]

# %%
comb_cols = temp[temp.columns[0]].unique()

# %%
comb_cols
# Out:
# array(['REGISTERED VOTERS - TOTAL                                             ',
#        'BALLOTS CAST - TOTAL                                                  ',
#        'BALLOTS CAST - DEMOCRAT                                               ',
#        'BALLOTS CAST - REPUBLICAN                                             ',
#        'BALLOTS CAST - NON-PARTISAN                                           ',
#        'BALLOTS CAST - BLANK                                                  ',
#        'UNITED STATES SENATOR                                                 ',
#        'UNITED STATES REPRESENTATIVE, 5TH CONGRESSIONAL DISTRICT              ',
#        'GOVERNOR                                                              ',
#        'ATTORNEY GENERAL                                                      ',
#        'ASSOCIATE JUSTICE OF THE SUPREME COURT, PLACE 5                       ',
#        'SECRETARY OF STATE                                                    ',
#        'STATE AUDITOR                                                         ',
#        'PUBLIC SERVICE COMMISSION, PLACE 1                                    ',
#        'PUBLIC SERVICE COMMISSION, PLACE 2                                    ',
#        'STATE BOARD OF EDUCATION MEMBER DISTRICT 8                            ',
#        'STATE SENATOR, DISTRICT 2                                             ',
#        'STATE REPRESENTATIVE, DISTRICT 4                                      ',
#        'STATE REPRESENTATIVE, DISTRICT 20                                     ',
#        'STATE REPRESENTATIVE, DISTRICT 25                                     ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (FEMALE), DISTRICT 4             ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 4               ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 6               ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (FEMALE), DISTRICT 10            ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 19              ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (FEMALE), DISTRICT 20            ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 20              ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (FEMALE), DISTRICT 21            ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 21              ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 22              ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (FEMALE), DISTRICT 25            ',
#        'STATE DEMOCRATIC EXECUTIVE COMMITTEE (MALE), DISTRICT 53              ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, PLACE 1          ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, PLACE 3          ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, DISTRICT 1       ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, DISTRICT 2       ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, DISTRICT 4       ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, DISTRICT 9       ',
#        'STATE REPUBLICAN EXECUTIVE COMMITTEE MADISON COUNTY, DISTRICT 11      ',
#        'PROPOSED STATEWIDE AMENDMENT NUMBER ONE (1)                           ',
#        '                                                                      ',
#        'MADISON COUNTY DEM EXEC COMM (F). DIST 6                              ',
#        'SUPERINTENDENT, MADISON COUNTY BOARD OF EDUCATION                     ',
#        'MADISON COUNTY REP BOARD OF EDUCATION DIST 5                          ',
#        'MADISON COUNTY REP EXEC COMM PL 4                       TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM PL 13                      TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM PL 15                      TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM DIST 2 PL 1                TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM DIST 3 PL 1                TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM DIST 6 PL 1                TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM DIST 9 PL 9                TRICT 11      ',
#        'MADISON COUNTY REP EXEC COMM DIST 11 PL 2               TRICT 11      '],
#       dtype=object)

# %%
contest_keywords = ['Senator', 'Representative', 'Governor', 'Attorney General', 'Secretary of State', 'State Auditor', 'State School Superintendent', 'Agriculture', 'Labor', 'Insurance', 'PSC', 'Public Service', 'Supreme Court', 'Court of Appeals', 'Amendment']

# %%
comb_list = []
for item in contest_keywords:
    temp = [i for i in comb_cols if item.upper() in i]
    comb_list += temp

# %%
comb_list
# Out:
# ['UNITED STATES SENATOR                                                 ',
#  'STATE SENATOR, DISTRICT 2                                             ',
#  'UNITED STATES REPRESENTATIVE, 5TH CONGRESSIONAL DISTRICT              ',
#  'STATE REPRESENTATIVE, DISTRICT 4                                      ',
#  'STATE REPRESENTATIVE, DISTRICT 20                                     ',
#  'STATE REPRESENTATIVE, DISTRICT 25                                     ',
#  'GOVERNOR                                                              ',
#  'ATTORNEY GENERAL                                                      ',
#  'SECRETARY OF STATE                                                    ',
#  'STATE AUDITOR                                                         ',
#  'PUBLIC SERVICE COMMISSION, PLACE 1                                    ',
#  'PUBLIC SERVICE COMMISSION, PLACE 2                                    ',
#  'ASSOCIATE JUSTICE OF THE SUPREME COURT, PLACE 5                       ',
#  'PROPOSED STATEWIDE AMENDMENT NUMBER ONE (1)                           ']

# %%
# Filter down to the races we want
comb_list = [i for i in comb.columns if "REPRESENTATIVE" in i] + [i for i in comb.columns if "GOVERNOR" in i] + [i for i in comb.columns if "SENATOR" in i] + [i for i in comb.columns if "ATTORNEY GENERAL" in i] + [i for i in comb.columns if "SECRETARY OF STATE" in i] + [i for i in comb.columns if "TREASURER" in i] + [i for i in comb.columns if "AUDITOR" in i] + [i for i in comb.columns if "AGRICULTURE" in i] + [i for i in comb.columns if "PUBLIC SERVICE" in i] + [i for i in comb.columns if "ASSOCIATE JUSTICE OF THE SUPREME COURT" in i] + [i for i in comb.columns if "CONSTITUTION OF ALABAMA" in i] + [i for i in comb.columns if "PROPOSED STATEWIDE AMENDMENT" in i]

# Remove the under votes and the over votes
comb_list = [i for i in comb_list if "Under Votes" not in i and "Over Votes" not in i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0b2145235ab1> in <module>
#       1 # Filter down to the races we want
# ----> 2 comb_list = [i for i in comb.columns if "REPRESENTATIVE" in i] + [i for i in comb.columns if "GOVERNOR" in i] + [i for i in comb.columns if "SENATOR" in i] + [i for i in comb.columns if "ATTORNEY GENERAL" in i] + [i for i in comb.columns if "SECRETARY OF STATE" in i] + [i for i in comb.columns if "TREASURER" in i] + [i for i in comb.columns if "AUDITOR" in i] + [i for i in comb.columns if "AGRICULTURE" in i] + [i for i in comb.columns if "PUBLIC SERVICE" in i] + [i for i in comb.columns if "ASSOCIATE JUSTICE OF THE SUPREME COURT" in i] + [i for i in comb.columns if "CONSTITUTION OF ALABAMA" in i] + [i for i in comb.columns if "PROPOSED STATEWIDE AMENDMENT" in i]
#       3
#       4 # Remove the under votes and the over votes
#       5 comb_list = [i for i in comb_list if "Under Votes" not in i and "Over Votes" not in i]
#
# NameError: name 'comb' is not defined

# %%
ga_22_primary_sw = ga_22_primary[ga_22_primary['contest'].isin(keep_contests)].copy()

# %% [markdown]
# <p><a name="check"></a></p>
#
# ### Vote Totals Check

# %% [markdown]
# <p><a name="discrepancies"></a></p>
#
# ### Checks

# %% [markdown]
# <p><a name="readme"></a></p>
#
# ### Creating README

# %% [markdown]
# <p><a name="exp"></a></p>
#
# ### Exporting Cleaned Precinct-Level Dataset
